# %% [markdown]
# # Imports

# %%
from causal_conv1d import causal_conv1d_fn

# %%
import fsspec
import hydra
import lightning as L
import numpy as np
import omegaconf
import rich.syntax
import rich.tree
import torch

import dataloader
import diffusion
import main
import utils
# Out:
# /home/tmp-user/miniconda3/envs/mdlm-310/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %% [markdown]
# # Sample generation

# %%
overrides=['mode=sample_eval',
           'eval.checkpoint_path=kuleshov-group/mdlm-no_flashattn-fp32-owt',
           'data=openwebtext-split',
           'model.length=1024',
           'sampling.predictor=adaptive',
           'sampling.steps=4000',
           'loader.eval_batch_size=1',
           'sampling.num_sample_batches=1',
           'backbone=hf_dit']

with hydra.initialize(version_base=None,
                      config_path='configs'):
  config = hydra.compose(config_name='config', overrides=overrides)
  sar_config = hydra.compose(config_name='config', overrides=overrides)

# %%
L.seed_everything(config.seed)

logger = utils.get_logger(__name__)   
tokenizer = dataloader.get_tokenizer(config)

samples = main.generate_samples(config, logger, tokenizer)
for sample in samples:
  print(sample)
# Out:
# Seed set to 1
# /home/tmp-user/miniconda3/envs/mdlm-310/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       3 logger = utils.get_logger(__name__)
#       4 tokenizer = dataloader.get_tokenizer(config)
# ----> 6 samples = main.generate_samples(config, logger, tokenizer)
#       7 for sample in samples:
#       8   print(sample)
#
# File ~/nima/01-test/main.py:110, in generate_samples(config, logger, tokenizer)
#     103   text_samples = intermediate_samples[-1]
#     104   # Note: Samples generated using semi-ar method
#     105   # need to to be processed before computing generative perplexity
#     106   # since these samples contain numerous <|endoftext|> tokens
#     107   # and diffusion.compute_generative_perplexity() discards
#     108   # any text after the first EOS token.
#     109 else:
# --> 110   samples = model.restore_model_and_sample(
#     111     num_steps=config.sampling.steps)
#     112   text_samples = model.tokenizer.batch_decode(samples)
#     113   model.compute_generative_perplexity(text_samples)
#
# File ~/nima/01-test/diffusion.py:792, in Diffusion.restore_model_and_sample(self, num_steps, eps)
#     790 self.backbone.eval()
#     791 self.noise.eval()
# --> 792 samples = self._sample(num_steps=num_steps, eps=eps)
#     793 if self.ema:
#     794   self.ema.restore(itertools.chain(
#     795     self.backbone.parameters(),
#     796     self.noise.parameters()))
#
# File ~/miniconda3/envs/mdlm-310/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/nima/01-test/diffusion.py:765, in Diffusion._sample(self, num_steps, eps)
#     763 # Changed
#     764 elif self.sampler == 'adaptive':
# --> 765   x = self._adaptive_update(x, t, dt)
#     766 # Changed
#     767 else:
#     768   x = self._analytic_update(x, t, dt)
#
# File ~/nima/01-test/diffusion.py:191, in Diffusion._adaptive_update(self, x, t, dt, gamma)
#     189 auto_gamma = (1.0 - mean_confidence) * move_chance_t
#     190 delta_m = move_chance_t - move_chance_s
# --> 191 assert False, Exception(auto_gamma)
#     193 p_remask = auto_gamma * delta_m
#     197 safe_m_t = torch.clamp(move_chance_t, min=1e-5)
#
# AssertionError: tensor([[[0.9990]]], device='cuda:0')

# %% [markdown]
# baseline: 25.39
#
# 0.6: 22.41
#
# 0.7: 22.47
#
# 0.8: 24.0022
#
# 1: 25.67
